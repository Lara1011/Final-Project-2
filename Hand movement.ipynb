# %%
import pandas as pd
import numpy as np
import glob

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegressionCV
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
Names = glob.glob(r'C:\Users\USER\OneDrive\שולחן העבודה\Training'+"/*")
li = []
for i,name in enumerate(Names):
    all_files = glob.glob(name + "/*.csv")
    situation = ["Spontan", "Sync" , "Alone"]

    for filename in all_files:
        f = pd.read_csv(filename, index_col=None, header=0)
        for j,label in enumerate(situation):
            if label in filename:
                f[" Name"] = i
                f[" Situations"] = j
                f = (f[f["Time"] > (f["Time"][0]+7)])
        li.append(f)

df = pd.concat(li, axis=0, ignore_index=True)

df.loc[(df[' Hand Type'] == 'left') , " Hand Type"] = int(0)
df.loc[(df[' Hand Type'] == 'right') , " Hand Type"] = int(1)
df[' Hand Type'] = df[' Hand Type'].astype(int)

# %%
df.head()
# Out:
#        Time   Frame ID   Hand Type   # hands   Position X   Position Y  \
# 0  71.41422      98073           0         2    -109.8061     228.3820
# 1  71.41422      98073           1         2     136.7226     201.6860
# 2  71.43108      98075           0         2    -110.4290     230.8011
# 3  71.43108      98075           1         2     137.0247     205.0279
# 4  71.44753      98076           0         2    -110.4223     231.4766
#
#     Position Z   Velocity X   Velocity Y   Velocity Z  ...   Wrist Pos Y  \
# 0     87.32578   -41.538020    116.70710    -60.09788  ...      186.2046
# 1    -35.08604     2.458278    189.46320    113.80700  ...      166.6150
# 2     86.41932   -23.842480    125.97130    -58.77163  ...      187.6303
# 3    -32.50590    10.029840    189.79200    155.60460  ...      167.4718
# 4     85.78614     0.774960     77.71951    -72.85492  ...      188.1121
#
#     Wrist Pos Z   Elbow pos X   Elbow Pos Y   Elbow Pos Z   Grab Strenth  \
# 0      53.51289     -346.8731     25.919320      27.82433            0.0
# 1      15.43945      313.4828      3.741617     144.85630            0.0
# 2      53.10642     -345.1480     25.046670      28.62841            0.0
# 3      16.26752      312.2578      1.103906     142.78720            0.0
# 4      52.70757     -345.9719     26.508460      28.25391            0.0
#
#     Grab Angle   Pinch Strength   Name   Situations
# 0     0.030295              0.0      0            0
# 1     0.229723              0.0      0            0
# 2     0.019477              0.0      0            0
# 3     0.233833              0.0      0            0
# 4     0.000000              0.0      0            0
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (300397, 24)

# %% [markdown]
# In order to have a numeric dataframe, we change the names,hands,situation to numbers

# %% [markdown]
# **Situation :** <br>
# Spontan - **0** <br>
# Sync - **1** <br>
# Alone - **2**

# %% [markdown]
# **Hand type :** <br>
# Left - **0** <br>
# Right - **1**

# %% [markdown]
# We also removed the first 7 seconds of each participant

# %%
df.isna().sum()
# Out:
# Time               0
#  Frame ID          0
#  Hand Type         0
#  # hands           0
#  Position X        0
#  Position Y        0
#  Position Z        0
#  Velocity X        0
#  Velocity Y        0
#  Velocity Z        0
#  Pitch             0
#  Roll              0
#  Yaw               0
#  Wrist Pos X       0
#  Wrist Pos Y       0
#  Wrist Pos Z       0
#  Elbow pos X       0
#  Elbow Pos Y       0
#  Elbow Pos Z       0
#  Grab Strenth      0
#  Grab Angle        0
#  Pinch Strength    0
#  Name              0
#  Situations        0
# dtype: int64

# %% [markdown]
# As we can tell there are no null values in the dataframe

# %%
p = df[(df[" # hands"]!=1)|(df[" Situations"]==2)]
df = p[(p[" # hands"]==1)|(p[" Situations"]!=2)]

# %%
HandRight=pd.read_csv(r"C:\Users\USER\OneDrive\שולחן העבודה\HandRight.csv",index_col=None,header=0)

# %%
HandRight.dropna(inplace = True)

# %%
HandRight = HandRight[HandRight[" Hand Type"]=='right']

# %% [markdown]
# ### Let's deal with each situation :
# Starting with **Alone**

# %%
Alone = df[df[" Situations"]==2]

# %%
l = []
right = HandRight
right.columns+="_"
for i in range(9):
    f = Alone[Alone[" Name"] == i]
    f.reset_index(inplace= True, drop = True)
    l.append(pd.concat([f, right], axis=1, ignore_index= False).dropna())

Alone = pd.concat(l, axis=0, ignore_index=True)
Alone.drop([" Name"], axis=1, inplace=True)

# %%
Alone.head()
# Out:
#        Time   Frame ID   Hand Type   # hands   Position X   Position Y  \
# 0  252.6601   118956.0         0.0       1.0    -117.1001     218.1561
# 1  252.6770   118958.0         0.0       1.0    -118.3450     220.6792
# 2  252.6934   118960.0         0.0       1.0    -120.1320     224.1188
# 3  252.7098   118962.0         0.0       1.0    -121.2949     226.8678
# 4  252.7263   118964.0         0.0       1.0    -121.9236     228.8240
#
#     Position Z   Velocity X   Velocity Y   Velocity Z  ...      Yaw_  \
# 0     138.0662    -53.72382     113.0561    138.40250  ... -0.277800
# 1     140.5435    -77.86527     151.4741    140.38970  ... -0.277763
# 2     143.2279   -104.69220     206.2707    153.16180  ... -0.278792
# 3     145.1182    -59.04000     142.4355     92.74687  ... -0.279768
# 4     146.0297    -41.81462     124.4137     50.71950  ... -0.278629
#
#     Wrist Pos X_   Wrist Pos Y_   Wrist Pos Z_   Elbow pos X_   Elbow Pos Y_  \
# 0       46.88831       207.3548       86.23589       203.8337       49.33507
# 1       47.54861       205.6568        86.4225       203.9553       47.88272
# 2        48.1503       204.5182       86.35149       204.6231       45.35921
# 3       48.64175       203.9989       86.16056       204.9939       44.18692
# 4       48.93135       203.3777       85.59017       204.5952       42.68003
#
#     Elbow Pos Z_   Grab Strenth_   Grab Angle_   Pinch Strength_
# 0       237.4553             0.0      0.206389               0.0
# 1       238.4482             0.0      0.243050               0.0
# 2       236.8544             0.0      0.281134               0.0
# 3       236.0927             0.0      0.277691               0.0
# 4       235.2896             0.0      0.283008               0.0
#
# [5 rows x 45 columns]

# %% [markdown]
# Now **Sync** or **Spontan**

# %%
SyncOrSpontan = df[df[' Situations']!=2]

# %%
Left = SyncOrSpontan[SyncOrSpontan[" Hand Type"]==0]

# %%
Right = SyncOrSpontan[SyncOrSpontan[" Hand Type"]==1]

# %%
Right.columns += "_"

# %%
SyncOrSpontan = pd.concat([Left,Right],axis=1)

# %%
SyncOrSpontan.reset_index(inplace=True)

# %%
SyncOrSpontan.drop([" Name"],axis=1,inplace=True)

# %%
SyncOrSpontan.head()
# Out:
#    index      Time   Frame ID   Hand Type   # hands   Position X   Position Y  \
# 0      0  71.41422    98073.0         0.0       2.0    -109.8061     228.3820
# 1      1       NaN        NaN         NaN       NaN          NaN          NaN
# 2      2  71.43108    98075.0         0.0       2.0    -110.4290     230.8011
# 3      3       NaN        NaN         NaN       NaN          NaN          NaN
# 4      4  71.44753    98076.0         0.0       2.0    -110.4223     231.4766
#
#     Position Z   Velocity X   Velocity Y  ...   Wrist Pos Y_   Wrist Pos Z_  \
# 0     87.32578    -41.53802    116.70710  ...            NaN            NaN
# 1          NaN          NaN          NaN  ...       166.6150       15.43945
# 2     86.41932    -23.84248    125.97130  ...            NaN            NaN
# 3          NaN          NaN          NaN  ...       167.4718       16.26752
# 4     85.78614      0.77496     77.71951  ...            NaN            NaN
#
#     Elbow pos X_   Elbow Pos Y_   Elbow Pos Z_   Grab Strenth_   Grab Angle_  \
# 0            NaN            NaN            NaN             NaN           NaN
# 1       313.4828       3.741617       144.8563             0.0      0.229723
# 2            NaN            NaN            NaN             NaN           NaN
# 3       312.2578       1.103906       142.7872             0.0      0.233833
# 4            NaN            NaN            NaN             NaN           NaN
#
#     Pinch Strength_   Name_   Situations_
# 0               NaN     NaN           NaN
# 1               0.0     0.0           0.0
# 2               NaN     NaN           NaN
# 3               0.0     0.0           0.0
# 4               NaN     NaN           NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# #### Now let's combine them into one dataframe for the whole dataset :

# %%
new_df = pd.concat([SyncOrSpontan,Alone],axis=0,ignore_index=True)

# %%
new_df = new_df.drop(["Time","index"," Hand Type"," Hand Type_","Time_"," # hands"," # hands_"," Name_"," Frame ID_"," Situations_"],axis=1)

# %% [markdown]
# We took every 10th row :

# %%
new_df=new_df[::10]

# %%
new_df.head()
# Out:
#      Frame ID   Position X   Position Y   Position Z   Velocity X  \
# 0     98073.0    -109.8061     228.3820     87.32578    -41.53802
# 10    98082.0    -112.5457     241.5983     82.42186    -71.08801
# 20    98092.0    -114.9085     259.3652     72.87430     24.98973
# 30    98101.0    -120.2698     273.1273     64.53665    -71.74786
# 40    98111.0    -122.3727     278.2248     70.00634    -47.98631
#
#      Velocity Y   Velocity Z     Pitch      Roll       Yaw  ...   Yaw_  \
# 0     116.70710    -60.09788  2.147859  0.867143  2.206444  ...    NaN
# 10    279.68930    -56.87809  2.050235  0.896647  2.147714  ...    NaN
# 20    181.82210   -106.73810  1.887583  0.920726  1.994715  ...    NaN
# 30    187.01230    -34.23848  1.781152  1.089296  1.990816  ...    NaN
# 40     27.11987    165.22750  1.780755  1.092412  1.992721  ...    NaN
#
#      Wrist Pos X_   Wrist Pos Y_   Wrist Pos Z_   Elbow pos X_   Elbow Pos Y_  \
# 0             NaN            NaN            NaN            NaN            NaN
# 10            NaN            NaN            NaN            NaN            NaN
# 20            NaN            NaN            NaN            NaN            NaN
# 30            NaN            NaN            NaN            NaN            NaN
# 40            NaN            NaN            NaN            NaN            NaN
#
#      Elbow Pos Z_   Grab Strenth_   Grab Angle_   Pinch Strength_
# 0             NaN             NaN           NaN               NaN
# 10            NaN             NaN           NaN               NaN
# 20            NaN             NaN           NaN               NaN
# 30            NaN             NaN           NaN               NaN
# 40            NaN             NaN           NaN               NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# Let's check if there are duplicated ID's, and remove them but only keep the lasts :

# %%
new_df.duplicated(subset=" Frame ID").sum()
# Out:
# 17754

# %%
new_df.loc[new_df[" Frame ID"].duplicated(),:].head()
# Out:
#        Frame ID   Position X   Position Y   Position Z   Velocity X  \
# 8220        NaN          NaN          NaN          NaN          NaN
# 8230        NaN          NaN          NaN          NaN          NaN
# 8240        NaN          NaN          NaN          NaN          NaN
# 8250        NaN          NaN          NaN          NaN          NaN
# 8260        NaN          NaN          NaN          NaN          NaN
#
#        Velocity Y   Velocity Z   Pitch   Roll   Yaw  ...      Yaw_  \
# 8220          NaN          NaN     NaN    NaN   NaN  ... -2.146385
# 8230          NaN          NaN     NaN    NaN   NaN  ... -2.148565
# 8240          NaN          NaN     NaN    NaN   NaN  ... -2.158652
# 8250          NaN          NaN     NaN    NaN   NaN  ... -2.153379
# 8260          NaN          NaN     NaN    NaN   NaN  ... -2.000205
#
#        Wrist Pos X_   Wrist Pos Y_   Wrist Pos Z_   Elbow pos X_  \
# 8220        87.4499        176.244        63.4177        284.103
# 8230         86.148        176.624        68.5792        284.213
# 8240        86.2498        174.468        69.5356        279.494
# 8250        85.8401        173.367        69.0777        279.659
# 8260        88.9467        173.596        66.6367        277.918
#
#        Elbow Pos Y_   Elbow Pos Z_   Grab Strenth_   Grab Angle_  \
# 8220        24.1057        47.2746             0.0       0.00000
# 8230        26.8019        48.5189             0.0       0.00000
# 8240        18.1457        52.2434             0.0       0.00000
# 8250        17.5559         53.712             0.0       0.00000
# 8260        11.6969        54.0939             0.0       0.02642
#
#        Pinch Strength_
# 8220               0.0
# 8230               0.0
# 8240               0.0
# 8250               0.0
# 8260               0.0
#
# [5 rows x 38 columns]

# %%
new_df=new_df.drop_duplicates(subset=" Frame ID")

# %%
new_df.shape
# Out:
# (10178, 38)

# %%
new_df.head()
# Out:
#      Frame ID   Position X   Position Y   Position Z   Velocity X  \
# 0     98073.0    -109.8061     228.3820     87.32578    -41.53802
# 10    98082.0    -112.5457     241.5983     82.42186    -71.08801
# 20    98092.0    -114.9085     259.3652     72.87430     24.98973
# 30    98101.0    -120.2698     273.1273     64.53665    -71.74786
# 40    98111.0    -122.3727     278.2248     70.00634    -47.98631
#
#      Velocity Y   Velocity Z     Pitch      Roll       Yaw  ...   Yaw_  \
# 0     116.70710    -60.09788  2.147859  0.867143  2.206444  ...    NaN
# 10    279.68930    -56.87809  2.050235  0.896647  2.147714  ...    NaN
# 20    181.82210   -106.73810  1.887583  0.920726  1.994715  ...    NaN
# 30    187.01230    -34.23848  1.781152  1.089296  1.990816  ...    NaN
# 40     27.11987    165.22750  1.780755  1.092412  1.992721  ...    NaN
#
#      Wrist Pos X_   Wrist Pos Y_   Wrist Pos Z_   Elbow pos X_   Elbow Pos Y_  \
# 0             NaN            NaN            NaN            NaN            NaN
# 10            NaN            NaN            NaN            NaN            NaN
# 20            NaN            NaN            NaN            NaN            NaN
# 30            NaN            NaN            NaN            NaN            NaN
# 40            NaN            NaN            NaN            NaN            NaN
#
#      Elbow Pos Z_   Grab Strenth_   Grab Angle_   Pinch Strength_
# 0             NaN             NaN           NaN               NaN
# 10            NaN             NaN           NaN               NaN
# 20            NaN             NaN           NaN               NaN
# 30            NaN             NaN           NaN               NaN
# 40            NaN             NaN           NaN               NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Let's train the dataset :

# %%
new_df.loc[(new_df[' Wrist Pos X_'].isnull()) , "  Wrist Pos X_"] = int(0)
new_df.loc[(new_df[' Wrist Pos Y_'].isnull()) , "  Wrist Pos Y_"] = int(0)
new_df.loc[(new_df[' Wrist Pos Z_'].isnull()) , "  Wrist Pos Z_"] = int(0)
new_df.loc[(new_df[' Elbow pos X_'].isnull()) , "  Elbow pos X_"] = int(0)
new_df.loc[(new_df[' Elbow Pos Y_'].isnull()) , "  Elbow Pos Y_"] = int(0)
new_df.loc[(new_df[' Elbow Pos Z_'].isnull()) , "  Elbow Pos Z_"] = int(0)

# %%
new_df[' Wrist Pos X_']=pd.to_numeric(new_df[' Wrist Pos X_'],errors = 'coerce')
new_df[' Wrist Pos Y_']=pd.to_numeric(new_df[' Wrist Pos Y_'],errors = 'coerce')
new_df[' Wrist Pos Z_']=pd.to_numeric(new_df[' Wrist Pos Z_'],errors = 'coerce')
new_df[' Elbow pos X_']=pd.to_numeric(new_df[' Elbow pos X_'],errors = 'coerce')
new_df[' Elbow Pos Y_']=pd.to_numeric(new_df[' Elbow Pos Y_'],errors = 'coerce')
new_df[' Elbow Pos Z_']=pd.to_numeric(new_df[' Elbow Pos Z_'],errors = 'coerce')

# %%
new_df = new_df.drop([' Wrist Pos X_', ' Wrist Pos Y_', ' Wrist Pos Z_',
       ' Elbow pos X_', ' Elbow Pos Y_', ' Elbow Pos Z_'],axis=1)

# %%
new_df=new_df.fillna(0)

# %%
new_df=new_df.round()

# %%
for i in new_df.columns:
    new_df[i]=new_df[i].astype(int)

# %%
new_df.head()
# Out:
#      Frame ID   Position X   Position Y   Position Z   Velocity X  \
# 0       98073         -110          228           87          -42
# 10      98082         -113          242           82          -71
# 20      98092         -115          259           73           25
# 30      98101         -120          273           65          -72
# 40      98111         -122          278           70          -48
#
#      Velocity Y   Velocity Z   Pitch   Roll   Yaw  ...   Yaw_   Grab Strenth_  \
# 0           117          -60       2      1     2  ...      0               0
# 10          280          -57       2      1     2  ...      0               0
# 20          182         -107       2      1     2  ...      0               0
# 30          187          -34       2      1     2  ...      0               0
# 40           27          165       2      1     2  ...      0               0
#
#      Grab Angle_   Pinch Strength_    Wrist Pos X_    Wrist Pos Y_  \
# 0              0                 0               0               0
# 10             0                 0               0               0
# 20             0                 0               0               0
# 30             0                 0               0               0
# 40             0                 0               0               0
#
#       Wrist Pos Z_    Elbow pos X_    Elbow Pos Y_    Elbow Pos Z_
# 0                0               0               0               0
# 10               0               0               0               0
# 20               0               0               0               0
# 30               0               0               0               0
# 40               0               0               0               0
#
# [5 rows x 38 columns]

# %%
X = new_df.drop(" Situations",axis=1)
Y = new_df[" Situations"]

# %% [markdown]
# ### Split the data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.33,random_state=42)

# %% [markdown]
# ### Logistic Regression classifier

# %%
LogisticRegression = LogisticRegressionCV()
LogisticRegression.fit(X, Y)
lr_pred = LogisticRegression.predict(X_test)
print(accuracy_score(Y_test, lr_pred))
print(classification_report(Y_test,lr_pred))
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9032450133968443
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86      1153
#            1       0.82      0.86      0.84      1007
#            2       1.00      1.00      1.00      1199
#
#     accuracy                           0.90      3359
#    macro avg       0.90      0.90      0.90      3359
# weighted avg       0.90      0.90      0.90      3359
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Random Forest classifier

# %%
RandomForestClassifier = RandomForestClassifier(max_depth=1)
RandomForestClassifier.fit(X, Y)
rf_pred = RandomForestClassifier.predict(X_test)
print(accuracy_score(Y_test, rf_pred))
print(classification_report(Y_test,rf_pred))
# Out:
# 0.7606430485263471
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74      1153
#            1       1.00      0.20      0.34      1007
#            2       1.00      1.00      1.00      1199
#
#     accuracy                           0.76      3359
#    macro avg       0.86      0.73      0.69      3359
# weighted avg       0.86      0.76      0.71      3359

# %% [markdown]
# ### XGBoost classifier

# %%
xgb = XGBClassifier(n_estimators =200,n_jobs=-1)
xgb.fit(X, Y)
xgb_pred = xgb.predict(X_test)
print(accuracy_score(Y_test, xgb_pred))
print(classification_report(Y_test,xgb_pred))
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:35:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1153
#            1       1.00      1.00      1.00      1007
#            2       1.00      1.00      1.00      1199
#
#     accuracy                           1.00      3359
#    macro avg       1.00      1.00      1.00      3359
# weighted avg       1.00      1.00      1.00      3359
# C:\Users\USER\anaconda3\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %% [markdown]
# ### KNeighbors classifier

# %%
knn = KNeighborsClassifier()
knn.fit(X, Y)
knn_pred = knn.predict(X_test)
print(accuracy_score(Y_test, knn_pred))
print(classification_report(Y_test,knn_pred))
# Out:
# 0.9857100327478416
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1153
#            1       0.97      1.00      0.98      1007
#            2       1.00      0.96      0.98      1199
#
#     accuracy                           0.99      3359
#    macro avg       0.99      0.99      0.99      3359
# weighted avg       0.99      0.99      0.99      3359

# %% [markdown]
# # Accuracy scores:
# - logistic regression : 0.90 <br>
# - random forest : 0.76 <br>
# - xgboost : 1.0 <br>
# - kneighbors : 0.98

# %% [markdown]
# ## Interesting results !
# We got an **1.0** accuracy score, using xgboost classifier !
